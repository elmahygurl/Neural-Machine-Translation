# %% [markdown]
# <a href="https://colab.research.google.com/github/elmahygurl/Neural-Machine-Translation/blob/main/Neural_Machine_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook for Programming in Problem 4
# Welcome to the programming portion of the assignment! Each assignment throughout the semester will have a written portion and a programming portion. We will be using [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb#recent=true), so if you have never used it before, take a quick look through this introduction: [Working with Google Colab](https://docs.google.com/document/d/1LlnXoOblXwW3YX-0yG_5seTXJsb3kRdMMRYqs8Qqum4/edit?usp=sharing).

# %% [markdown]
# ## Learning Objectives
# In this problem, we will use [PyTorch](https://pytorch.org/) to implement a sequence-to-sequence (seq2seq) transformer model to build a nerual machine translation (NMT) system, which translates from French to English.

# %% [markdown]
# ## Writing Code
# Look for the keyword "TODO" and fill in your code in the empty space.
# You can edit code in the other parts of the notebook too, which can be useful for debugging, but be careful to avoid breaking the provided code.

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
# !pip install torch==1.8.0
# or for GPU support:
# !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1
# Out:
# Requirement already satisfied: transformers==4.27.0 in /usr/local/lib/python3.10/dist-packages (4.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2024.2.2)
# Requirement already satisfied: datasets==2.10.0 in /usr/local/lib/python3.10/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (1.25.2)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (14.0.2)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.9.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (24.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (3.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.10.0) (1.16.0)

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget --quiet https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -qo resources.zip

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk
raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`
    # Print example to understand its structure
    #print(example)

    # Assuming the keys are 'text_en' for English and 'text_fr' for French
    source_text = example["text_fr"]
    target_text = example["text_en"]

    # Tokenize the source text (French)
    source_encoded = source_tokenizer(source_text, truncation=True, padding='max_length') #trial:, max_length=128
    # Tokenize the target text (English)
    target_encoded = target_tokenizer(target_text, truncation=True, padding='max_length')

    return {
        "encoder_input_ids": source_encoded['input_ids'],
        "decoder_input_ids": target_encoded['input_ids']
    }

# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])
# Print a few examples to visualize and do a sanity check
for i in range(3):
    example = tokenized_datasets["train"][i]
    print(f"Example {i}:")
    print(f"Encoder input IDs: {example['encoder_input_ids']}")
    print(f"Decoder input IDs: {example['decoder_input_ids']}")
    print("Source text (decoded):", source_tokenizer.decode(example['encoder_input_ids'], skip_special_tokens=True))
    print("Target text (decoded):", target_tokenizer.decode(example['decoder_input_ids'], skip_special_tokens=True))
    print()
# Out:
# Map:   0%|          | 0/8701 [00:00<?, ? examples/s]
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Map:   0%|          | 0/485 [00:00<?, ? examples/s]
# Map:   0%|          | 0/486 [00:00<?, ? examples/s]
# Example 0:
# Encoder input IDs: [1, 47, 60, 1449, 36, 2]
# Decoder input IDs: [1, 37, 42, 1044, 35, 2]
# Source text (decoded): ▁je ▁suis ▁dure ▁.
# Target text (decoded): ▁i ▁m ▁tough ▁.
#
# Example 1:
# Encoder input IDs: [1, 47, 86, 60, 68, 531, 1037, 385, 36, 2]
# Decoder input IDs: [1, 37, 42, 60, 89, 39, 259, 2914, 35, 2]
# Source text (decoded): ▁je ▁ne ▁suis ▁pas ▁aux ▁pie ces ▁.
# Target text (decoded): ▁i ▁m ▁not ▁in ▁a ▁r ush ▁.
#
# Example 2:
# Encoder input IDs: [1, 47, 86, 48, 883, 68, 239, 36, 2]
# Decoder input IDs: [1, 37, 42, 60, 1678, 501, 35, 2]
# Source text (decoded): ▁je ▁ne ▁d ors ▁pas ▁bien ▁.
# Target text (decoded): ▁i ▁m ▁not ▁sleeping ▁well ▁.

# %%
 #Example dataset as before
example_dataset = [
    {"text_en": "we have an example", "text_fr": "nous avons un exemple"}
]
mapped_example = map_example(example_dataset[0])

print("Mapped example:", mapped_example)
# Out:
# Mapped example: {'encoder_input_ids': [1, 79, 349, 82, 298, 13, 130, 52, 2], 'decoder_input_ids': [1, 64, 324, 103, 266, 1490, 92, 2]}

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head
        self.num_attention_heads = num_attention_heads
        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention

        # Query, Key, and Value projections
        self.query_proj = nn.Linear(hidden_size, hidden_size)
        self.key_proj = nn.Linear(hidden_size, hidden_size)
        self.value_proj = nn.Linear(hidden_size, hidden_size)

        # Output projection
        self.out_proj = nn.Linear(hidden_size, hidden_size)

    def causal_attention_mask(self,
                              sequence_length: int,
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.

        mask = torch.triu(torch.ones((sequence_length, sequence_length), device=device) * float('-inf'), diagonal=1)
        return mask.unsqueeze(0).unsqueeze(0)  # (1, 1, sequence_length, sequence_length)


    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)
        batch_size, sequence_length, hidden_size = hidden_states.size()

        if self.is_cross_attention:
            # Cross-attention: keys and values come from the encoder outputs
            query = self.query_proj(hidden_states)
            key = self.key_proj(encoder_outputs)
            value = self.value_proj(encoder_outputs)
            key_padding_mask = key_padding_mask[:, :encoder_outputs.size(1)]
        else:
            # Self-attention: keys and values come from the hidden states
            query = self.query_proj(hidden_states)
            key = self.key_proj(hidden_states)
            value = self.value_proj(hidden_states)

        # Reshape to separate heads
        query = query.view(batch_size, sequence_length, self.num_attention_heads, self.head_dim).transpose(1, 2)
        key = key.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)
        value = value.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)

        # Scaled dot-product attention
        attn_scores = torch.einsum("bhqd, bhkd -> bhqk", query, key) / (self.head_dim ** 0.5)

        # Apply key padding mask
        attn_scores = attn_scores.masked_fill(key_padding_mask.unsqueeze(1).unsqueeze(2), float('-inf'))

        # Apply causal mask if needed
        if self.is_causal_attention:
            causal_mask = self.causal_attention_mask(sequence_length, device=hidden_states.device)
            attn_scores = attn_scores + causal_mask

        # Softmax to get attention weights
        attn_weights = torch.softmax(attn_scores, dim=-1)

        # Attention output
        attn_output = torch.einsum("bhqk, bhkd -> bhqd", attn_weights, value)

        # Combine heads
        attn_output = attn_output.transpose(1, 2).contiguous().view(batch_size, sequence_length, hidden_size)

        # Final linear projection
        output = self.out_proj(attn_output)

        return output, attn_weights

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt

def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function
    plt.figure(figsize=(8, 6))
    plt.imshow(attention_matrix, aspect='auto', cmap='viridis')
    plt.colorbar()
    plt.title(title)
    plt.xlabel("Key token position")
    plt.ylabel("Query token position")
    plt.show()



plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings
        # Initialize token and position embeddings
        self.token_embeddings = nn.Embedding(vocab_size, hidden_size)
        self.position_embeddings = nn.Embedding(max_sequence_length, hidden_size)

        # Store the maximum sequence length
        self.max_sequence_length = max_sequence_length

    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.

        # Compute the logits using the token embedding weights
        logits = torch.matmul(decoder_output, self.token_embeddings.weight.T)
        return logits
    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!
        batch_size, sequence_length = input_ids.size()

        # Create position ids from 0 to sequence_length - 1
        position_ids = torch.arange(sequence_length, dtype=torch.long, device=input_ids.device)
        position_ids = position_ids.unsqueeze(0).expand(batch_size, sequence_length)

        # Get token and position embeddings
        token_embeds = self.token_embeddings(input_ids)
        position_embeds = self.position_embeddings(position_ids)

        # Sum the token and position embeddings
        embeddings = token_embeds + position_embeds
        return embeddings

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.
        # Define input embeddings for source and target tokens
        self.source_embeddings = TransformerEmbeddings(source_vocab_size, hidden_size, max_sequence_length)
        self.target_embeddings = TransformerEmbeddings(target_vocab_size, hidden_size, max_sequence_length)

        # Define encoder blocks
        self.encoder = nn.ModuleList([
            TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob)
            for _ in range(num_encoder_layers)
        ])

        # Define decoder blocks
        self.decoder = nn.ModuleList([
            TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob, is_decoder=True)
            for _ in range(num_decoder_layers)
        ])

        # Define output projection layer
        self.output_projection = nn.Linear(hidden_size, target_vocab_size)

    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        # TODO Implement this function
        # Get source token embeddings
        source_embeddings = self.source_embeddings(input_ids)

        # Forward pass through encoder blocks
        encoder_hidden_states = source_embeddings
        for encoder_block in self.encoder:
            encoder_hidden_states = encoder_block(encoder_hidden_states, padding_mask)

        return encoder_hidden_states

    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        # TODO Implement this function

        # Get target token embeddings
        target_embeddings = self.target_embeddings(input_ids)

        # Forward pass through decoder blocks
        decoder_hidden_states = target_embeddings
        for decoder_block in self.decoder:
            decoder_hidden_states = decoder_block(decoder_hidden_states, padding_mask, encoder_outputs, encoder_padding_mask)

        # Project to target vocabulary size
        decoder_logits = self.output_projection(decoder_hidden_states)

        return decoder_logits

    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)

    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)

    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)

    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction='none')


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=10, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')


    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()

        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32,
    intermediate_size=32 * 4,
    num_attention_heads=4,
    num_encoder_layers=3,
    num_decoder_layers=3,
    max_sequence_length=32,
    hidden_dropout_prob=0.1,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=15, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (source_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 32)
#     (position_embeddings): Embedding(32, 32)
#   )
#   (target_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 32)
#     (position_embeddings): Embedding(32, 32)
#   )
#   (encoder): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (out_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (out_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (out_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (output_projection): Linear(in_features=32, out_features=3200, bias=True)
# )
# Total number of trainable model parameters: 401536
# Use device: cpu
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=54.63 avg_ppl=2358.93 speed=1499.52 words/sec time_elapsed=1.50 sec
# epoch 1 (19/272) | step 20 | avg_nll=52.07 avg_ppl=1272.41 speed=2203.04 words/sec time_elapsed=2.56 sec
# epoch 1 (29/272) | step 30 | avg_nll=48.55 avg_ppl=772.99 speed=2145.67 words/sec time_elapsed=3.65 sec
# epoch 1 (39/272) | step 40 | avg_nll=44.56 avg_ppl=479.65 speed=1890.88 words/sec time_elapsed=4.87 sec
# epoch 1 (49/272) | step 50 | avg_nll=41.38 avg_ppl=314.97 speed=2198.83 words/sec time_elapsed=5.92 sec
# epoch 1 (59/272) | step 60 | avg_nll=38.03 avg_ppl=202.82 speed=2401.08 words/sec time_elapsed=6.88 sec
# epoch 1 (69/272) | step 70 | avg_nll=35.38 avg_ppl=135.50 speed=1570.03 words/sec time_elapsed=8.35 sec
# epoch 1 (79/272) | step 80 | avg_nll=33.81 avg_ppl=105.78 speed=875.14 words/sec time_elapsed=11.00 sec
# epoch 1 (89/272) | step 90 | avg_nll=31.68 avg_ppl=76.52 speed=1257.18 words/sec time_elapsed=12.86 sec
# epoch 1 (99/272) | step 100 | avg_nll=29.19 avg_ppl=60.06 speed=1894.99 words/sec time_elapsed=14.07 sec
# Begin validation ...
# validation: step 100 | dev_ppl=50.30553436279297
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=28.03 avg_ppl=49.83 speed=1145.21 words/sec time_elapsed=16.07 sec
# epoch 1 (119/272) | step 120 | avg_nll=26.84 avg_ppl=41.90 speed=1772.49 words/sec time_elapsed=17.37 sec
# epoch 1 (129/272) | step 130 | avg_nll=27.52 avg_ppl=41.95 speed=1360.65 words/sec time_elapsed=19.10 sec
# epoch 1 (139/272) | step 140 | avg_nll=26.12 avg_ppl=35.75 speed=1745.87 words/sec time_elapsed=20.44 sec
# epoch 1 (149/272) | step 150 | avg_nll=25.46 avg_ppl=32.96 speed=1441.35 words/sec time_elapsed=22.06 sec
# epoch 1 (159/272) | step 160 | avg_nll=25.33 avg_ppl=32.46 speed=836.34 words/sec time_elapsed=24.84 sec
# epoch 1 (169/272) | step 170 | avg_nll=23.96 avg_ppl=28.05 speed=1732.22 words/sec time_elapsed=26.17 sec
# epoch 1 (179/272) | step 180 | avg_nll=25.11 avg_ppl=29.93 speed=3313.63 words/sec time_elapsed=26.89 sec
# epoch 1 (189/272) | step 190 | avg_nll=23.85 avg_ppl=26.90 speed=3343.00 words/sec time_elapsed=27.58 sec
# epoch 1 (199/272) | step 200 | avg_nll=23.19 avg_ppl=25.73 speed=3780.12 words/sec time_elapsed=28.18 sec
# Begin validation ...
# validation: step 200 | dev_ppl=22.024646759033203
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=22.30 avg_ppl=22.64 speed=2283.12 words/sec time_elapsed=29.19 sec
# epoch 1 (219/272) | step 220 | avg_nll=22.95 avg_ppl=23.58 speed=3444.76 words/sec time_elapsed=29.86 sec
# epoch 1 (229/272) | step 230 | avg_nll=23.36 avg_ppl=24.22 speed=3860.89 words/sec time_elapsed=30.47 sec
# epoch 1 (239/272) | step 240 | avg_nll=22.35 avg_ppl=21.26 speed=3419.83 words/sec time_elapsed=31.15 sec
# epoch 1 (249/272) | step 250 | avg_nll=23.04 avg_ppl=23.40 speed=3371.41 words/sec time_elapsed=31.85 sec
# epoch 1 (259/272) | step 260 | avg_nll=22.19 avg_ppl=21.22 speed=3434.66 words/sec time_elapsed=32.52 sec
# epoch 1 (269/272) | step 270 | avg_nll=21.25 avg_ppl=19.12 speed=3455.30 words/sec time_elapsed=33.19 sec
# epoch 2 (7/272) | step 280 | avg_nll=21.66 avg_ppl=19.93 speed=3421.42 words/sec time_elapsed=33.87 sec
# epoch 2 (17/272) | step 290 | avg_nll=20.35 avg_ppl=17.48 speed=3391.58 words/sec time_elapsed=34.54 sec
# epoch 2 (27/272) | step 300 | avg_nll=21.26 avg_ppl=18.04 speed=3236.82 words/sec time_elapsed=35.27 sec
# Begin validation ...
# validation: step 300 | dev_ppl=17.335166931152344
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=20.38 avg_ppl=17.40 speed=1737.14 words/sec time_elapsed=36.58 sec
# epoch 2 (47/272) | step 320 | avg_nll=21.09 avg_ppl=18.62 speed=2762.78 words/sec time_elapsed=37.42 sec
# epoch 2 (57/272) | step 330 | avg_nll=21.59 avg_ppl=18.42 speed=2449.07 words/sec time_elapsed=38.39 sec
# epoch 2 (67/272) | step 340 | avg_nll=20.60 avg_ppl=17.12 speed=3223.11 words/sec time_elapsed=39.11 sec
# epoch 2 (77/272) | step 350 | avg_nll=20.35 avg_ppl=16.25 speed=3346.22 words/sec time_elapsed=39.81 sec
# epoch 2 (87/272) | step 360 | avg_nll=20.92 avg_ppl=18.24 speed=3462.32 words/sec time_elapsed=40.47 sec
# epoch 2 (97/272) | step 370 | avg_nll=19.81 avg_ppl=16.08 speed=3226.29 words/sec time_elapsed=41.18 sec
# epoch 2 (107/272) | step 380 | avg_nll=19.34 avg_ppl=14.71 speed=3180.92 words/sec time_elapsed=41.90 sec
# epoch 2 (117/272) | step 390 | avg_nll=20.22 avg_ppl=15.81 speed=3485.83 words/sec time_elapsed=42.58 sec
# epoch 2 (127/272) | step 400 | avg_nll=20.23 avg_ppl=16.48 speed=3580.94 words/sec time_elapsed=43.22 sec
# Begin validation ...
# validation: step 400 | dev_ppl=14.879033088684082
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=20.97 avg_ppl=16.67 speed=2486.00 words/sec time_elapsed=44.18 sec
# epoch 2 (147/272) | step 420 | avg_nll=21.00 avg_ppl=17.42 speed=3408.60 words/sec time_elapsed=44.87 sec
# epoch 2 (157/272) | step 430 | avg_nll=19.29 avg_ppl=14.46 speed=3743.83 words/sec time_elapsed=45.49 sec
# epoch 2 (167/272) | step 440 | avg_nll=20.00 avg_ppl=15.60 speed=3806.63 words/sec time_elapsed=46.10 sec
# epoch 2 (177/272) | step 450 | avg_nll=19.49 avg_ppl=14.63 speed=3494.67 words/sec time_elapsed=46.77 sec
# epoch 2 (187/272) | step 460 | avg_nll=19.83 avg_ppl=15.38 speed=3250.77 words/sec time_elapsed=47.48 sec
# epoch 2 (197/272) | step 470 | avg_nll=19.84 avg_ppl=15.47 speed=3307.25 words/sec time_elapsed=48.18 sec
# epoch 2 (207/272) | step 480 | avg_nll=19.67 avg_ppl=14.86 speed=2577.71 words/sec time_elapsed=49.09 sec
# epoch 2 (217/272) | step 490 | avg_nll=18.76 avg_ppl=13.88 speed=2526.38 words/sec time_elapsed=49.99 sec
# epoch 2 (227/272) | step 500 | avg_nll=19.49 avg_ppl=14.81 speed=2277.89 words/sec time_elapsed=51.01 sec
# Begin validation ...
# validation: step 500 | dev_ppl=13.63797378540039
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=18.78 avg_ppl=12.79 speed=2026.25 words/sec time_elapsed=52.17 sec
# epoch 2 (247/272) | step 520 | avg_nll=18.58 avg_ppl=13.46 speed=3869.85 words/sec time_elapsed=52.76 sec
# epoch 2 (257/272) | step 530 | avg_nll=17.84 avg_ppl=12.17 speed=3870.32 words/sec time_elapsed=53.35 sec
# epoch 2 (267/272) | step 540 | avg_nll=18.61 avg_ppl=13.30 speed=3971.25 words/sec time_elapsed=53.93 sec
# epoch 3 (5/272) | step 550 | avg_nll=17.88 avg_ppl=12.15 speed=3298.40 words/sec time_elapsed=54.63 sec
# epoch 3 (15/272) | step 560 | avg_nll=18.25 avg_ppl=12.62 speed=3415.46 words/sec time_elapsed=55.30 sec
# epoch 3 (25/272) | step 570 | avg_nll=17.94 avg_ppl=11.71 speed=3917.01 words/sec time_elapsed=55.90 sec
# epoch 3 (35/272) | step 580 | avg_nll=18.11 avg_ppl=12.49 speed=3859.85 words/sec time_elapsed=56.49 sec
# epoch 3 (45/272) | step 590 | avg_nll=18.29 avg_ppl=12.40 speed=3833.50 words/sec time_elapsed=57.10 sec
# epoch 3 (55/272) | step 600 | avg_nll=17.62 avg_ppl=11.60 speed=3812.57 words/sec time_elapsed=57.70 sec
# Begin validation ...
# validation: step 600 | dev_ppl=12.10177230834961
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=17.15 avg_ppl=10.91 speed=2554.11 words/sec time_elapsed=58.60 sec
# epoch 3 (75/272) | step 620 | avg_nll=17.70 avg_ppl=11.37 speed=3861.88 words/sec time_elapsed=59.21 sec
# epoch 3 (85/272) | step 630 | avg_nll=18.14 avg_ppl=12.11 speed=3058.22 words/sec time_elapsed=59.97 sec
# epoch 3 (95/272) | step 640 | avg_nll=17.92 avg_ppl=11.64 speed=3261.36 words/sec time_elapsed=60.68 sec
# epoch 3 (105/272) | step 650 | avg_nll=17.87 avg_ppl=11.68 speed=3324.30 words/sec time_elapsed=61.38 sec
# epoch 3 (115/272) | step 660 | avg_nll=18.49 avg_ppl=12.28 speed=2492.46 words/sec time_elapsed=62.33 sec
# epoch 3 (125/272) | step 670 | avg_nll=17.10 avg_ppl=11.10 speed=2317.04 words/sec time_elapsed=63.32 sec
# epoch 3 (135/272) | step 680 | avg_nll=18.11 avg_ppl=11.72 speed=2238.59 words/sec time_elapsed=64.37 sec
# epoch 3 (145/272) | step 690 | avg_nll=16.94 avg_ppl=10.59 speed=2870.66 words/sec time_elapsed=65.17 sec
# epoch 3 (155/272) | step 700 | avg_nll=17.80 avg_ppl=11.56 speed=3849.44 words/sec time_elapsed=65.78 sec
# Begin validation ...
# validation: step 700 | dev_ppl=11.383760452270508
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=17.15 avg_ppl=10.73 speed=2360.15 words/sec time_elapsed=66.76 sec
# epoch 3 (175/272) | step 720 | avg_nll=18.04 avg_ppl=11.92 speed=3288.08 words/sec time_elapsed=67.46 sec
# epoch 3 (185/272) | step 730 | avg_nll=17.31 avg_ppl=11.15 speed=3170.69 words/sec time_elapsed=68.19 sec
# epoch 3 (195/272) | step 740 | avg_nll=17.81 avg_ppl=11.77 speed=3656.90 words/sec time_elapsed=68.82 sec
# epoch 3 (205/272) | step 750 | avg_nll=17.96 avg_ppl=11.70 speed=3962.14 words/sec time_elapsed=69.41 sec
# epoch 3 (215/272) | step 760 | avg_nll=17.76 avg_ppl=11.47 speed=3715.18 words/sec time_elapsed=70.04 sec
# epoch 3 (225/272) | step 770 | avg_nll=17.75 avg_ppl=11.44 speed=3845.23 words/sec time_elapsed=70.64 sec
# epoch 3 (235/272) | step 780 | avg_nll=17.90 avg_ppl=11.62 speed=3880.87 words/sec time_elapsed=71.25 sec
# epoch 3 (245/272) | step 790 | avg_nll=16.30 avg_ppl=9.62 speed=3676.10 words/sec time_elapsed=71.87 sec
# epoch 3 (255/272) | step 800 | avg_nll=16.99 avg_ppl=10.63 speed=3457.04 words/sec time_elapsed=72.54 sec
# Begin validation ...
# validation: step 800 | dev_ppl=10.335407257080078
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=16.82 avg_ppl=10.22 speed=2368.58 words/sec time_elapsed=73.52 sec
# epoch 4 (3/272) | step 820 | avg_nll=15.95 avg_ppl=9.56 speed=3737.66 words/sec time_elapsed=74.12 sec
# epoch 4 (13/272) | step 830 | avg_nll=16.22 avg_ppl=9.57 speed=3946.69 words/sec time_elapsed=74.70 sec
# epoch 4 (23/272) | step 840 | avg_nll=16.79 avg_ppl=9.94 speed=2956.07 words/sec time_elapsed=75.50 sec
# epoch 4 (33/272) | step 850 | avg_nll=16.95 avg_ppl=10.05 speed=2746.41 words/sec time_elapsed=76.35 sec
# epoch 4 (43/272) | step 860 | avg_nll=16.04 avg_ppl=9.42 speed=2474.45 words/sec time_elapsed=77.28 sec
# epoch 4 (53/272) | step 870 | avg_nll=16.21 avg_ppl=9.05 speed=2697.58 words/sec time_elapsed=78.15 sec
# epoch 4 (63/272) | step 880 | avg_nll=15.99 avg_ppl=9.22 speed=3345.77 words/sec time_elapsed=78.84 sec
# epoch 4 (73/272) | step 890 | avg_nll=16.30 avg_ppl=9.45 speed=3848.43 words/sec time_elapsed=79.44 sec
# epoch 4 (83/272) | step 900 | avg_nll=16.30 avg_ppl=9.68 speed=3698.93 words/sec time_elapsed=80.07 sec
# Begin validation ...
# validation: step 900 | dev_ppl=9.812176704406738
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=15.76 avg_ppl=8.53 speed=2439.77 words/sec time_elapsed=81.03 sec
# epoch 4 (103/272) | step 920 | avg_nll=15.94 avg_ppl=9.28 speed=3432.39 words/sec time_elapsed=81.70 sec
# epoch 4 (113/272) | step 930 | avg_nll=15.88 avg_ppl=8.86 speed=3354.18 words/sec time_elapsed=82.39 sec
# epoch 4 (123/272) | step 940 | avg_nll=14.97 avg_ppl=8.17 speed=3288.52 words/sec time_elapsed=83.09 sec
# epoch 4 (133/272) | step 950 | avg_nll=15.69 avg_ppl=8.59 speed=3125.76 words/sec time_elapsed=83.83 sec
# epoch 4 (143/272) | step 960 | avg_nll=14.34 avg_ppl=7.65 speed=3745.31 words/sec time_elapsed=84.44 sec
# epoch 4 (153/272) | step 970 | avg_nll=15.84 avg_ppl=8.69 speed=3732.25 words/sec time_elapsed=85.06 sec
# epoch 4 (163/272) | step 980 | avg_nll=16.20 avg_ppl=9.53 speed=3589.16 words/sec time_elapsed=85.70 sec
# epoch 4 (173/272) | step 990 | avg_nll=15.91 avg_ppl=9.04 speed=3345.30 words/sec time_elapsed=86.40 sec
# epoch 4 (183/272) | step 1000 | avg_nll=16.80 avg_ppl=10.21 speed=3342.65 words/sec time_elapsed=87.09 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=9.220876693725586
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=16.06 avg_ppl=9.04 speed=2073.62 words/sec time_elapsed=88.21 sec
# epoch 4 (203/272) | step 1020 | avg_nll=15.62 avg_ppl=8.42 speed=2409.10 words/sec time_elapsed=89.19 sec
# epoch 4 (213/272) | step 1030 | avg_nll=15.84 avg_ppl=8.95 speed=2277.95 words/sec time_elapsed=90.20 sec
# epoch 4 (223/272) | step 1040 | avg_nll=15.86 avg_ppl=8.83 speed=2345.65 words/sec time_elapsed=91.20 sec
# epoch 4 (233/272) | step 1050 | avg_nll=15.99 avg_ppl=8.82 speed=3384.61 words/sec time_elapsed=91.89 sec
# epoch 4 (243/272) | step 1060 | avg_nll=15.76 avg_ppl=8.94 speed=3449.25 words/sec time_elapsed=92.56 sec
# epoch 4 (253/272) | step 1070 | avg_nll=15.29 avg_ppl=8.20 speed=3102.32 words/sec time_elapsed=93.31 sec
# epoch 4 (263/272) | step 1080 | avg_nll=14.40 avg_ppl=7.55 speed=3274.76 words/sec time_elapsed=94.01 sec
# epoch 5 (1/272) | step 1090 | avg_nll=15.20 avg_ppl=8.23 speed=3250.09 words/sec time_elapsed=94.72 sec
# epoch 5 (11/272) | step 1100 | avg_nll=15.09 avg_ppl=7.90 speed=3205.70 words/sec time_elapsed=95.45 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=8.67812728881836
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=14.92 avg_ppl=7.65 speed=2186.83 words/sec time_elapsed=96.52 sec
# epoch 5 (31/272) | step 1120 | avg_nll=13.71 avg_ppl=6.81 speed=3059.42 words/sec time_elapsed=97.27 sec
# epoch 5 (41/272) | step 1130 | avg_nll=13.75 avg_ppl=6.81 speed=3246.29 words/sec time_elapsed=97.98 sec
# epoch 5 (51/272) | step 1140 | avg_nll=15.02 avg_ppl=7.55 speed=3469.33 words/sec time_elapsed=98.66 sec
# epoch 5 (61/272) | step 1150 | avg_nll=14.24 avg_ppl=7.05 speed=3233.29 words/sec time_elapsed=99.38 sec
# epoch 5 (71/272) | step 1160 | avg_nll=15.36 avg_ppl=8.30 speed=3168.61 words/sec time_elapsed=100.12 sec
# epoch 5 (81/272) | step 1170 | avg_nll=14.80 avg_ppl=7.43 speed=3239.02 words/sec time_elapsed=100.84 sec
# epoch 5 (91/272) | step 1180 | avg_nll=14.61 avg_ppl=7.60 speed=2970.71 words/sec time_elapsed=101.62 sec
# epoch 5 (101/272) | step 1190 | avg_nll=14.43 avg_ppl=7.46 speed=2509.69 words/sec time_elapsed=102.54 sec
# epoch 5 (111/272) | step 1200 | avg_nll=14.77 avg_ppl=7.55 speed=2243.43 words/sec time_elapsed=103.58 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=8.296404838562012
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=14.38 avg_ppl=7.46 speed=1638.14 words/sec time_elapsed=104.98 sec
# epoch 5 (131/272) | step 1220 | avg_nll=14.37 avg_ppl=7.27 speed=3144.07 words/sec time_elapsed=105.72 sec
# epoch 5 (141/272) | step 1230 | avg_nll=14.23 avg_ppl=7.06 speed=3446.44 words/sec time_elapsed=106.39 sec
# epoch 5 (151/272) | step 1240 | avg_nll=13.64 avg_ppl=6.79 speed=3961.84 words/sec time_elapsed=106.97 sec
# epoch 5 (161/272) | step 1250 | avg_nll=13.10 avg_ppl=6.24 speed=3783.81 words/sec time_elapsed=107.57 sec
# epoch 5 (171/272) | step 1260 | avg_nll=13.43 avg_ppl=6.55 speed=3694.59 words/sec time_elapsed=108.19 sec
# epoch 5 (181/272) | step 1270 | avg_nll=14.54 avg_ppl=7.59 speed=4152.19 words/sec time_elapsed=108.75 sec
# epoch 5 (191/272) | step 1280 | avg_nll=13.85 avg_ppl=6.77 speed=4063.82 words/sec time_elapsed=109.32 sec
# epoch 5 (201/272) | step 1290 | avg_nll=14.30 avg_ppl=7.14 speed=4184.12 words/sec time_elapsed=109.87 sec
# epoch 5 (211/272) | step 1300 | avg_nll=14.21 avg_ppl=7.25 speed=3932.89 words/sec time_elapsed=110.46 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=7.872757434844971
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=14.10 avg_ppl=7.15 speed=2403.95 words/sec time_elapsed=111.41 sec
# epoch 5 (231/272) | step 1320 | avg_nll=15.43 avg_ppl=8.09 speed=3775.07 words/sec time_elapsed=112.04 sec
# epoch 5 (241/272) | step 1330 | avg_nll=14.42 avg_ppl=7.17 speed=3685.64 words/sec time_elapsed=112.67 sec
# epoch 5 (251/272) | step 1340 | avg_nll=14.16 avg_ppl=7.14 speed=3369.77 words/sec time_elapsed=113.36 sec
# epoch 5 (261/272) | step 1350 | avg_nll=15.13 avg_ppl=8.00 speed=3532.66 words/sec time_elapsed=114.02 sec
# epoch 5 (271/272) | step 1360 | avg_nll=13.64 avg_ppl=6.75 speed=3611.25 words/sec time_elapsed=114.65 sec
# epoch 6 (9/272) | step 1370 | avg_nll=13.91 avg_ppl=6.60 speed=2373.85 words/sec time_elapsed=115.64 sec
# epoch 6 (19/272) | step 1380 | avg_nll=13.09 avg_ppl=5.94 speed=2560.51 words/sec time_elapsed=116.56 sec
# epoch 6 (29/272) | step 1390 | avg_nll=12.52 avg_ppl=5.76 speed=2325.47 words/sec time_elapsed=117.55 sec
# epoch 6 (39/272) | step 1400 | avg_nll=13.66 avg_ppl=6.41 speed=2677.93 words/sec time_elapsed=118.43 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=7.63429594039917
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=13.74 avg_ppl=6.43 speed=2268.73 words/sec time_elapsed=119.47 sec
# epoch 6 (59/272) | step 1420 | avg_nll=13.91 avg_ppl=6.81 speed=3322.00 words/sec time_elapsed=120.17 sec
# epoch 6 (69/272) | step 1430 | avg_nll=12.35 avg_ppl=5.64 speed=3170.42 words/sec time_elapsed=120.89 sec
# epoch 6 (79/272) | step 1440 | avg_nll=12.75 avg_ppl=5.86 speed=3373.32 words/sec time_elapsed=121.57 sec
# epoch 6 (89/272) | step 1450 | avg_nll=13.68 avg_ppl=6.62 speed=3687.91 words/sec time_elapsed=122.20 sec
# epoch 6 (99/272) | step 1460 | avg_nll=12.22 avg_ppl=5.52 speed=3899.92 words/sec time_elapsed=122.79 sec
# epoch 6 (109/272) | step 1470 | avg_nll=13.93 avg_ppl=6.79 speed=3884.86 words/sec time_elapsed=123.39 sec
# epoch 6 (119/272) | step 1480 | avg_nll=13.07 avg_ppl=6.12 speed=1992.89 words/sec time_elapsed=124.54 sec
# epoch 6 (129/272) | step 1490 | avg_nll=13.34 avg_ppl=6.31 speed=1756.75 words/sec time_elapsed=125.86 sec
# epoch 6 (139/272) | step 1500 | avg_nll=13.47 avg_ppl=6.37 speed=1979.86 words/sec time_elapsed=127.04 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=7.360482215881348
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=12.84 avg_ppl=5.97 speed=2469.00 words/sec time_elapsed=127.97 sec
# epoch 6 (159/272) | step 1520 | avg_nll=13.10 avg_ppl=6.07 speed=2826.39 words/sec time_elapsed=128.79 sec
# epoch 6 (169/272) | step 1530 | avg_nll=13.82 avg_ppl=6.69 speed=2687.87 words/sec time_elapsed=129.66 sec
# epoch 6 (179/272) | step 1540 | avg_nll=12.45 avg_ppl=5.67 speed=2300.48 words/sec time_elapsed=130.66 sec
# epoch 6 (189/272) | step 1550 | avg_nll=12.99 avg_ppl=6.02 speed=2428.73 words/sec time_elapsed=131.61 sec
# epoch 6 (199/272) | step 1560 | avg_nll=12.43 avg_ppl=5.58 speed=3460.41 words/sec time_elapsed=132.28 sec
# epoch 6 (209/272) | step 1570 | avg_nll=13.63 avg_ppl=6.50 speed=3260.19 words/sec time_elapsed=133.00 sec
# epoch 6 (219/272) | step 1580 | avg_nll=13.21 avg_ppl=6.18 speed=3670.22 words/sec time_elapsed=133.63 sec
# epoch 6 (229/272) | step 1590 | avg_nll=12.90 avg_ppl=6.12 speed=3765.01 words/sec time_elapsed=134.24 sec
# epoch 6 (239/272) | step 1600 | avg_nll=12.86 avg_ppl=5.90 speed=4000.21 words/sec time_elapsed=134.82 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=6.998519420623779
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=13.20 avg_ppl=6.26 speed=2395.04 words/sec time_elapsed=135.78 sec
# epoch 6 (259/272) | step 1620 | avg_nll=12.97 avg_ppl=6.02 speed=3231.32 words/sec time_elapsed=136.49 sec
# epoch 6 (269/272) | step 1630 | avg_nll=12.77 avg_ppl=5.81 speed=3374.81 words/sec time_elapsed=137.18 sec
# epoch 7 (7/272) | step 1640 | avg_nll=11.97 avg_ppl=5.25 speed=3693.53 words/sec time_elapsed=137.81 sec
# epoch 7 (17/272) | step 1650 | avg_nll=11.05 avg_ppl=4.65 speed=3768.25 words/sec time_elapsed=138.42 sec
# epoch 7 (27/272) | step 1660 | avg_nll=11.99 avg_ppl=5.15 speed=3772.59 words/sec time_elapsed=139.04 sec
# epoch 7 (37/272) | step 1670 | avg_nll=11.89 avg_ppl=5.15 speed=4034.17 words/sec time_elapsed=139.61 sec
# epoch 7 (47/272) | step 1680 | avg_nll=12.41 avg_ppl=5.41 speed=3731.37 words/sec time_elapsed=140.24 sec
# epoch 7 (57/272) | step 1690 | avg_nll=11.55 avg_ppl=5.06 speed=3315.44 words/sec time_elapsed=140.93 sec
# epoch 7 (67/272) | step 1700 | avg_nll=12.64 avg_ppl=5.50 speed=3132.44 words/sec time_elapsed=141.69 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=6.794333457946777
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=11.23 avg_ppl=4.87 speed=1510.76 words/sec time_elapsed=143.19 sec
# epoch 7 (87/272) | step 1720 | avg_nll=11.68 avg_ppl=5.04 speed=2206.14 words/sec time_elapsed=144.24 sec
# epoch 7 (97/272) | step 1730 | avg_nll=11.68 avg_ppl=4.95 speed=2476.24 words/sec time_elapsed=145.19 sec
# epoch 7 (107/272) | step 1740 | avg_nll=12.03 avg_ppl=5.42 speed=3117.59 words/sec time_elapsed=145.92 sec
# epoch 7 (117/272) | step 1750 | avg_nll=12.87 avg_ppl=5.79 speed=3211.54 words/sec time_elapsed=146.65 sec
# epoch 7 (127/272) | step 1760 | avg_nll=12.79 avg_ppl=5.72 speed=3390.56 words/sec time_elapsed=147.34 sec
# epoch 7 (137/272) | step 1770 | avg_nll=11.86 avg_ppl=5.14 speed=3419.86 words/sec time_elapsed=148.02 sec
# epoch 7 (147/272) | step 1780 | avg_nll=12.55 avg_ppl=5.58 speed=3419.76 words/sec time_elapsed=148.70 sec
# epoch 7 (157/272) | step 1790 | avg_nll=11.32 avg_ppl=4.85 speed=3136.56 words/sec time_elapsed=149.43 sec
# epoch 7 (167/272) | step 1800 | avg_nll=12.19 avg_ppl=5.40 speed=3140.75 words/sec time_elapsed=150.17 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=6.693475723266602
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=11.49 avg_ppl=4.88 speed=2161.29 words/sec time_elapsed=151.24 sec
# epoch 7 (187/272) | step 1820 | avg_nll=12.00 avg_ppl=5.29 speed=3497.15 words/sec time_elapsed=151.90 sec
# epoch 7 (197/272) | step 1830 | avg_nll=12.52 avg_ppl=5.55 speed=3883.05 words/sec time_elapsed=152.50 sec
# epoch 7 (207/272) | step 1840 | avg_nll=12.00 avg_ppl=5.25 speed=3743.56 words/sec time_elapsed=153.12 sec
# epoch 7 (217/272) | step 1850 | avg_nll=12.14 avg_ppl=5.49 speed=3855.25 words/sec time_elapsed=153.71 sec
# epoch 7 (227/272) | step 1860 | avg_nll=12.80 avg_ppl=5.75 speed=3969.77 words/sec time_elapsed=154.30 sec
# epoch 7 (237/272) | step 1870 | avg_nll=11.04 avg_ppl=4.62 speed=3945.29 words/sec time_elapsed=154.89 sec
# epoch 7 (247/272) | step 1880 | avg_nll=11.69 avg_ppl=5.02 speed=2799.59 words/sec time_elapsed=155.72 sec
# epoch 7 (257/272) | step 1890 | avg_nll=11.32 avg_ppl=4.87 speed=2539.01 words/sec time_elapsed=156.62 sec
# epoch 7 (267/272) | step 1900 | avg_nll=11.50 avg_ppl=5.04 speed=2514.64 words/sec time_elapsed=157.52 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=6.447020053863525
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=12.36 avg_ppl=5.30 speed=1839.96 words/sec time_elapsed=158.81 sec
# epoch 8 (15/272) | step 1920 | avg_nll=11.39 avg_ppl=4.63 speed=3715.65 words/sec time_elapsed=159.45 sec
# epoch 8 (25/272) | step 1930 | avg_nll=10.36 avg_ppl=4.27 speed=3829.60 words/sec time_elapsed=160.05 sec
# epoch 8 (35/272) | step 1940 | avg_nll=10.50 avg_ppl=4.33 speed=3799.11 words/sec time_elapsed=160.65 sec
# epoch 8 (45/272) | step 1950 | avg_nll=11.08 avg_ppl=4.53 speed=3366.97 words/sec time_elapsed=161.35 sec
# epoch 8 (55/272) | step 1960 | avg_nll=11.36 avg_ppl=4.73 speed=3286.50 words/sec time_elapsed=162.06 sec
# epoch 8 (65/272) | step 1970 | avg_nll=10.69 avg_ppl=4.37 speed=3498.22 words/sec time_elapsed=162.73 sec
# epoch 8 (75/272) | step 1980 | avg_nll=10.51 avg_ppl=4.31 speed=2981.32 words/sec time_elapsed=163.50 sec
# epoch 8 (85/272) | step 1990 | avg_nll=10.94 avg_ppl=4.51 speed=2338.31 words/sec time_elapsed=164.49 sec
# epoch 8 (95/272) | step 2000 | avg_nll=11.07 avg_ppl=4.69 speed=2595.72 words/sec time_elapsed=165.38 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=6.4357500076293945
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=10.50 avg_ppl=4.21 speed=1169.63 words/sec time_elapsed=167.38 sec
# epoch 8 (115/272) | step 2020 | avg_nll=10.65 avg_ppl=4.45 speed=1146.87 words/sec time_elapsed=169.37 sec
# epoch 8 (125/272) | step 2030 | avg_nll=11.00 avg_ppl=4.64 speed=967.29 words/sec time_elapsed=171.74 sec
# epoch 8 (135/272) | step 2040 | avg_nll=10.20 avg_ppl=4.16 speed=1394.43 words/sec time_elapsed=173.39 sec
# epoch 8 (145/272) | step 2050 | avg_nll=11.62 avg_ppl=4.89 speed=1607.16 words/sec time_elapsed=174.85 sec
# epoch 8 (155/272) | step 2060 | avg_nll=10.95 avg_ppl=4.55 speed=1394.73 words/sec time_elapsed=176.51 sec
# epoch 8 (165/272) | step 2070 | avg_nll=11.52 avg_ppl=4.94 speed=1625.28 words/sec time_elapsed=177.93 sec
# epoch 8 (175/272) | step 2080 | avg_nll=11.19 avg_ppl=4.69 speed=1557.02 words/sec time_elapsed=179.42 sec
# epoch 8 (185/272) | step 2090 | avg_nll=10.60 avg_ppl=4.38 speed=1728.89 words/sec time_elapsed=180.75 sec
# epoch 8 (195/272) | step 2100 | avg_nll=10.94 avg_ppl=4.51 speed=1477.68 words/sec time_elapsed=182.32 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=6.302468776702881
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=11.20 avg_ppl=4.65 speed=990.88 words/sec time_elapsed=184.68 sec
# epoch 8 (215/272) | step 2120 | avg_nll=10.59 avg_ppl=4.34 speed=1222.31 words/sec time_elapsed=186.57 sec
# epoch 8 (225/272) | step 2130 | avg_nll=11.13 avg_ppl=4.57 speed=2285.97 words/sec time_elapsed=187.60 sec
# epoch 8 (235/272) | step 2140 | avg_nll=11.08 avg_ppl=4.70 speed=2267.57 words/sec time_elapsed=188.61 sec
# epoch 8 (245/272) | step 2150 | avg_nll=11.23 avg_ppl=4.66 speed=2369.61 words/sec time_elapsed=189.59 sec
# epoch 8 (255/272) | step 2160 | avg_nll=10.67 avg_ppl=4.44 speed=1706.30 words/sec time_elapsed=190.94 sec
# epoch 8 (265/272) | step 2170 | avg_nll=11.43 avg_ppl=4.83 speed=2033.51 words/sec time_elapsed=192.08 sec
# epoch 9 (3/272) | step 2180 | avg_nll=10.23 avg_ppl=4.08 speed=2462.04 words/sec time_elapsed=193.03 sec
# epoch 9 (13/272) | step 2190 | avg_nll=9.04 avg_ppl=3.61 speed=3505.44 words/sec time_elapsed=193.67 sec
# epoch 9 (23/272) | step 2200 | avg_nll=9.84 avg_ppl=3.87 speed=3960.99 words/sec time_elapsed=194.26 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=6.028085708618164
# epoch 9 step 2200: save currently the best model to 'model.pt'
# epoch 9 (33/272) | step 2210 | avg_nll=9.86 avg_ppl=3.97 speed=2176.79 words/sec time_elapsed=195.31 sec
# epoch 9 (43/272) | step 2220 | avg_nll=10.26 avg_ppl=4.12 speed=3146.16 words/sec time_elapsed=196.05 sec
# epoch 9 (53/272) | step 2230 | avg_nll=9.79 avg_ppl=3.87 speed=2644.32 words/sec time_elapsed=196.92 sec
# epoch 9 (63/272) | step 2240 | avg_nll=10.09 avg_ppl=4.03 speed=2421.54 words/sec time_elapsed=197.88 sec
# epoch 9 (73/272) | step 2250 | avg_nll=9.34 avg_ppl=3.75 speed=2388.46 words/sec time_elapsed=198.83 sec
# epoch 9 (83/272) | step 2260 | avg_nll=9.86 avg_ppl=3.89 speed=2632.14 words/sec time_elapsed=199.71 sec
# epoch 9 (93/272) | step 2270 | avg_nll=9.64 avg_ppl=3.73 speed=3025.90 words/sec time_elapsed=200.48 sec
# epoch 9 (103/272) | step 2280 | avg_nll=10.14 avg_ppl=4.10 speed=3795.59 words/sec time_elapsed=201.09 sec
# epoch 9 (113/272) | step 2290 | avg_nll=10.45 avg_ppl=4.19 speed=3793.06 words/sec time_elapsed=201.71 sec
# epoch 9 (123/272) | step 2300 | avg_nll=9.84 avg_ppl=3.88 speed=3572.32 words/sec time_elapsed=202.36 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=5.939603328704834
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=9.83 avg_ppl=3.88 speed=2213.15 words/sec time_elapsed=203.40 sec
# epoch 9 (143/272) | step 2320 | avg_nll=9.88 avg_ppl=3.93 speed=3352.30 words/sec time_elapsed=204.09 sec
# epoch 9 (153/272) | step 2330 | avg_nll=9.90 avg_ppl=3.85 speed=3362.36 words/sec time_elapsed=204.79 sec
# epoch 9 (163/272) | step 2340 | avg_nll=10.08 avg_ppl=4.03 speed=3238.70 words/sec time_elapsed=205.51 sec
# epoch 9 (173/272) | step 2350 | avg_nll=10.32 avg_ppl=4.09 speed=3403.16 words/sec time_elapsed=206.20 sec
# epoch 9 (183/272) | step 2360 | avg_nll=9.77 avg_ppl=3.90 speed=3553.50 words/sec time_elapsed=206.84 sec
# epoch 9 (193/272) | step 2370 | avg_nll=9.95 avg_ppl=4.02 speed=3456.63 words/sec time_elapsed=207.51 sec
# epoch 9 (203/272) | step 2380 | avg_nll=10.32 avg_ppl=4.12 speed=3282.84 words/sec time_elapsed=208.22 sec
# epoch 9 (213/272) | step 2390 | avg_nll=9.37 avg_ppl=3.69 speed=3478.98 words/sec time_elapsed=208.88 sec
# epoch 9 (223/272) | step 2400 | avg_nll=10.57 avg_ppl=4.22 speed=3875.95 words/sec time_elapsed=209.48 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=5.951430320739746
# epoch 9 (233/272) | step 2410 | avg_nll=10.09 avg_ppl=3.98 speed=1901.08 words/sec time_elapsed=210.71 sec
# epoch 9 (243/272) | step 2420 | avg_nll=10.66 avg_ppl=4.29 speed=2354.79 words/sec time_elapsed=211.71 sec
# epoch 9 (253/272) | step 2430 | avg_nll=10.07 avg_ppl=4.01 speed=2598.66 words/sec time_elapsed=212.60 sec
# epoch 9 (263/272) | step 2440 | avg_nll=10.27 avg_ppl=4.08 speed=3013.34 words/sec time_elapsed=213.38 sec
# epoch 10 (1/272) | step 2450 | avg_nll=9.58 avg_ppl=3.79 speed=3803.81 words/sec time_elapsed=213.98 sec
# epoch 10 (11/272) | step 2460 | avg_nll=8.97 avg_ppl=3.48 speed=3156.02 words/sec time_elapsed=214.71 sec
# epoch 10 (21/272) | step 2470 | avg_nll=9.68 avg_ppl=3.80 speed=3154.08 words/sec time_elapsed=215.45 sec
# epoch 10 (31/272) | step 2480 | avg_nll=8.99 avg_ppl=3.44 speed=3142.93 words/sec time_elapsed=216.19 sec
# epoch 10 (41/272) | step 2490 | avg_nll=8.83 avg_ppl=3.32 speed=3299.84 words/sec time_elapsed=216.91 sec
# epoch 10 (51/272) | step 2500 | avg_nll=9.03 avg_ppl=3.50 speed=3280.75 words/sec time_elapsed=217.61 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=5.755066394805908
# epoch 10 step 2500: save currently the best model to 'model.pt'
# epoch 10 (61/272) | step 2510 | avg_nll=8.87 avg_ppl=3.46 speed=2115.82 words/sec time_elapsed=218.69 sec
# epoch 10 (71/272) | step 2520 | avg_nll=8.81 avg_ppl=3.40 speed=3588.70 words/sec time_elapsed=219.33 sec
# epoch 10 (81/272) | step 2530 | avg_nll=8.81 avg_ppl=3.37 speed=3731.99 words/sec time_elapsed=219.96 sec
# epoch 10 (91/272) | step 2540 | avg_nll=9.26 avg_ppl=3.55 speed=3410.60 words/sec time_elapsed=220.64 sec
# epoch 10 (101/272) | step 2550 | avg_nll=9.75 avg_ppl=3.79 speed=3554.18 words/sec time_elapsed=221.30 sec
# epoch 10 (111/272) | step 2560 | avg_nll=9.18 avg_ppl=3.49 speed=3369.79 words/sec time_elapsed=222.00 sec
# epoch 10 (121/272) | step 2570 | avg_nll=8.80 avg_ppl=3.35 speed=3413.88 words/sec time_elapsed=222.68 sec
# epoch 10 (131/272) | step 2580 | avg_nll=9.80 avg_ppl=3.93 speed=2885.97 words/sec time_elapsed=223.47 sec
# epoch 10 (141/272) | step 2590 | avg_nll=9.78 avg_ppl=3.76 speed=2569.04 words/sec time_elapsed=224.40 sec
# epoch 10 (151/272) | step 2600 | avg_nll=8.94 avg_ppl=3.45 speed=2583.05 words/sec time_elapsed=225.29 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=5.730888366699219
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=8.87 avg_ppl=3.43 speed=1574.32 words/sec time_elapsed=226.75 sec
# epoch 10 (171/272) | step 2620 | avg_nll=9.21 avg_ppl=3.55 speed=3217.13 words/sec time_elapsed=227.48 sec
# epoch 10 (181/272) | step 2630 | avg_nll=8.88 avg_ppl=3.43 speed=3443.50 words/sec time_elapsed=228.15 sec
# epoch 10 (191/272) | step 2640 | avg_nll=8.94 avg_ppl=3.50 speed=3382.08 words/sec time_elapsed=228.82 sec
# epoch 10 (201/272) | step 2650 | avg_nll=8.74 avg_ppl=3.26 speed=3382.67 words/sec time_elapsed=229.52 sec
# epoch 10 (211/272) | step 2660 | avg_nll=8.81 avg_ppl=3.39 speed=3655.24 words/sec time_elapsed=230.16 sec
# epoch 10 (221/272) | step 2670 | avg_nll=8.74 avg_ppl=3.46 speed=3494.33 words/sec time_elapsed=230.80 sec
# epoch 10 (231/272) | step 2680 | avg_nll=9.70 avg_ppl=3.78 speed=3556.28 words/sec time_elapsed=231.46 sec
# epoch 10 (241/272) | step 2690 | avg_nll=8.70 avg_ppl=3.41 speed=3300.37 words/sec time_elapsed=232.14 sec
# epoch 10 (251/272) | step 2700 | avg_nll=8.61 avg_ppl=3.30 speed=3786.57 words/sec time_elapsed=232.75 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=5.656057834625244
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=10.41 avg_ppl=4.13 speed=2296.75 words/sec time_elapsed=233.78 sec
# epoch 10 (271/272) | step 2720 | avg_nll=8.68 avg_ppl=3.33 speed=3426.40 words/sec time_elapsed=234.45 sec
# epoch 11 (9/272) | step 2730 | avg_nll=7.61 avg_ppl=2.87 speed=3758.93 words/sec time_elapsed=235.07 sec
# epoch 11 (19/272) | step 2740 | avg_nll=7.69 avg_ppl=2.97 speed=3378.12 words/sec time_elapsed=235.74 sec
# epoch 11 (29/272) | step 2750 | avg_nll=9.35 avg_ppl=3.53 speed=2942.31 words/sec time_elapsed=236.54 sec
# epoch 11 (39/272) | step 2760 | avg_nll=8.11 avg_ppl=3.07 speed=2356.99 words/sec time_elapsed=237.52 sec
# epoch 11 (49/272) | step 2770 | avg_nll=7.66 avg_ppl=2.84 speed=2451.63 words/sec time_elapsed=238.48 sec
# epoch 11 (59/272) | step 2780 | avg_nll=7.94 avg_ppl=3.04 speed=2154.11 words/sec time_elapsed=239.54 sec
# epoch 11 (69/272) | step 2790 | avg_nll=8.17 avg_ppl=3.14 speed=3002.75 words/sec time_elapsed=240.31 sec
# epoch 11 (79/272) | step 2800 | avg_nll=7.79 avg_ppl=2.98 speed=3611.37 words/sec time_elapsed=240.94 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=5.755591869354248
# epoch 11 (89/272) | step 2810 | avg_nll=8.04 avg_ppl=3.06 speed=2503.28 words/sec time_elapsed=241.86 sec
# epoch 11 (99/272) | step 2820 | avg_nll=8.10 avg_ppl=3.02 speed=4100.52 words/sec time_elapsed=242.43 sec
# epoch 11 (109/272) | step 2830 | avg_nll=7.86 avg_ppl=2.98 speed=3465.80 words/sec time_elapsed=243.09 sec
# epoch 11 (119/272) | step 2840 | avg_nll=8.88 avg_ppl=3.35 speed=3450.55 words/sec time_elapsed=243.78 sec
# epoch 11 (129/272) | step 2850 | avg_nll=8.05 avg_ppl=3.04 speed=3387.27 words/sec time_elapsed=244.46 sec
# epoch 11 (139/272) | step 2860 | avg_nll=8.88 avg_ppl=3.37 speed=3673.63 words/sec time_elapsed=245.10 sec
# epoch 11 (149/272) | step 2870 | avg_nll=7.66 avg_ppl=2.92 speed=3690.81 words/sec time_elapsed=245.72 sec
# epoch 11 (159/272) | step 2880 | avg_nll=8.32 avg_ppl=3.17 speed=3259.71 words/sec time_elapsed=246.43 sec
# epoch 11 (169/272) | step 2890 | avg_nll=8.55 avg_ppl=3.25 speed=3266.74 words/sec time_elapsed=247.14 sec
# epoch 11 (179/272) | step 2900 | avg_nll=8.28 avg_ppl=3.13 speed=3362.58 words/sec time_elapsed=247.83 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=5.716769695281982
# epoch 11 (189/272) | step 2910 | avg_nll=8.20 avg_ppl=3.11 speed=2244.89 words/sec time_elapsed=248.86 sec
# epoch 11 (199/272) | step 2920 | avg_nll=8.30 avg_ppl=3.17 speed=3353.99 words/sec time_elapsed=249.55 sec
# epoch 11 (209/272) | step 2930 | avg_nll=8.60 avg_ppl=3.26 speed=2427.15 words/sec time_elapsed=250.51 sec
# epoch 11 (219/272) | step 2940 | avg_nll=8.59 avg_ppl=3.26 speed=2239.87 words/sec time_elapsed=251.55 sec
# epoch 11 (229/272) | step 2950 | avg_nll=8.99 avg_ppl=3.42 speed=2479.63 words/sec time_elapsed=252.49 sec
# epoch 11 (239/272) | step 2960 | avg_nll=8.33 avg_ppl=3.13 speed=2996.72 words/sec time_elapsed=253.27 sec
# epoch 11 (249/272) | step 2970 | avg_nll=9.07 avg_ppl=3.43 speed=3386.32 words/sec time_elapsed=253.97 sec
# epoch 11 (259/272) | step 2980 | avg_nll=8.55 avg_ppl=3.28 speed=3297.07 words/sec time_elapsed=254.67 sec
# epoch 11 (269/272) | step 2990 | avg_nll=8.38 avg_ppl=3.25 speed=3440.43 words/sec time_elapsed=255.33 sec
# epoch 12 (7/272) | step 3000 | avg_nll=7.25 avg_ppl=2.78 speed=3707.95 words/sec time_elapsed=255.94 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=5.743962287902832
# epoch 12 (17/272) | step 3010 | avg_nll=6.99 avg_ppl=2.66 speed=2529.32 words/sec time_elapsed=256.85 sec
# epoch 12 (27/272) | step 3020 | avg_nll=7.37 avg_ppl=2.76 speed=3616.98 words/sec time_elapsed=257.49 sec
# epoch 12 (37/272) | step 3030 | avg_nll=7.39 avg_ppl=2.83 speed=3609.06 words/sec time_elapsed=258.12 sec
# epoch 12 (47/272) | step 3040 | avg_nll=6.70 avg_ppl=2.61 speed=3336.58 words/sec time_elapsed=258.79 sec
# epoch 12 (57/272) | step 3050 | avg_nll=7.64 avg_ppl=2.88 speed=3691.17 words/sec time_elapsed=259.41 sec
# epoch 12 (67/272) | step 3060 | avg_nll=7.46 avg_ppl=2.84 speed=3629.99 words/sec time_elapsed=260.04 sec
# epoch 12 (77/272) | step 3070 | avg_nll=7.61 avg_ppl=2.88 speed=3276.07 words/sec time_elapsed=260.75 sec
# epoch 12 (87/272) | step 3080 | avg_nll=7.38 avg_ppl=2.73 speed=3768.05 words/sec time_elapsed=261.37 sec
# epoch 12 (97/272) | step 3090 | avg_nll=7.49 avg_ppl=2.82 speed=3664.06 words/sec time_elapsed=262.00 sec
# epoch 12 (107/272) | step 3100 | avg_nll=8.05 avg_ppl=2.99 speed=3597.87 words/sec time_elapsed=262.66 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=5.56973123550415
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=7.30 avg_ppl=2.74 speed=1636.97 words/sec time_elapsed=264.07 sec
# epoch 12 (127/272) | step 3120 | avg_nll=7.66 avg_ppl=2.84 speed=2330.06 words/sec time_elapsed=265.08 sec
# epoch 12 (137/272) | step 3130 | avg_nll=7.19 avg_ppl=2.64 speed=2315.09 words/sec time_elapsed=266.11 sec
# epoch 12 (147/272) | step 3140 | avg_nll=7.61 avg_ppl=2.84 speed=3228.82 words/sec time_elapsed=266.83 sec
# epoch 12 (157/272) | step 3150 | avg_nll=7.32 avg_ppl=2.75 speed=3335.80 words/sec time_elapsed=267.52 sec
# epoch 12 (167/272) | step 3160 | avg_nll=7.21 avg_ppl=2.70 speed=3393.52 words/sec time_elapsed=268.21 sec
# epoch 12 (177/272) | step 3170 | avg_nll=7.68 avg_ppl=2.83 speed=3261.97 words/sec time_elapsed=268.93 sec
# epoch 12 (187/272) | step 3180 | avg_nll=7.47 avg_ppl=2.82 speed=3340.97 words/sec time_elapsed=269.62 sec
# epoch 12 (197/272) | step 3190 | avg_nll=7.67 avg_ppl=2.88 speed=3285.59 words/sec time_elapsed=270.33 sec
# epoch 12 (207/272) | step 3200 | avg_nll=8.07 avg_ppl=3.00 speed=3392.95 words/sec time_elapsed=271.02 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=5.50862979888916
# epoch 12 step 3200: save currently the best model to 'model.pt'
# epoch 12 (217/272) | step 3210 | avg_nll=7.92 avg_ppl=3.00 speed=2169.94 words/sec time_elapsed=272.08 sec
# epoch 12 (227/272) | step 3220 | avg_nll=7.90 avg_ppl=2.93 speed=3640.39 words/sec time_elapsed=272.73 sec
# epoch 12 (237/272) | step 3230 | avg_nll=8.50 avg_ppl=3.17 speed=3789.80 words/sec time_elapsed=273.35 sec
# epoch 12 (247/272) | step 3240 | avg_nll=7.53 avg_ppl=2.85 speed=2020.27 words/sec time_elapsed=274.49 sec
# epoch 12 (257/272) | step 3250 | avg_nll=8.26 avg_ppl=3.13 speed=1700.48 words/sec time_elapsed=275.85 sec
# epoch 12 (267/272) | step 3260 | avg_nll=7.60 avg_ppl=2.88 speed=1262.92 words/sec time_elapsed=277.67 sec
# epoch 13 (5/272) | step 3270 | avg_nll=6.87 avg_ppl=2.62 speed=1441.70 words/sec time_elapsed=279.26 sec
# epoch 13 (15/272) | step 3280 | avg_nll=6.77 avg_ppl=2.55 speed=1727.97 words/sec time_elapsed=280.60 sec
# epoch 13 (25/272) | step 3290 | avg_nll=6.76 avg_ppl=2.52 speed=2213.87 words/sec time_elapsed=281.65 sec
# epoch 13 (35/272) | step 3300 | avg_nll=6.63 avg_ppl=2.49 speed=2390.86 words/sec time_elapsed=282.63 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=5.488207817077637
# epoch 13 step 3300: save currently the best model to 'model.pt'
# epoch 13 (45/272) | step 3310 | avg_nll=6.53 avg_ppl=2.47 speed=1369.25 words/sec time_elapsed=284.31 sec
# epoch 13 (55/272) | step 3320 | avg_nll=6.45 avg_ppl=2.47 speed=2364.87 words/sec time_elapsed=285.28 sec
# epoch 13 (65/272) | step 3330 | avg_nll=6.96 avg_ppl=2.62 speed=2546.30 words/sec time_elapsed=286.19 sec
# epoch 13 (75/272) | step 3340 | avg_nll=6.09 avg_ppl=2.34 speed=2987.32 words/sec time_elapsed=286.96 sec
# epoch 13 (85/272) | step 3350 | avg_nll=6.39 avg_ppl=2.46 speed=3129.42 words/sec time_elapsed=287.68 sec
# epoch 13 (95/272) | step 3360 | avg_nll=7.33 avg_ppl=2.73 speed=3391.61 words/sec time_elapsed=288.37 sec
# epoch 13 (105/272) | step 3370 | avg_nll=6.58 avg_ppl=2.47 speed=3377.34 words/sec time_elapsed=289.06 sec
# epoch 13 (115/272) | step 3380 | avg_nll=6.63 avg_ppl=2.49 speed=3730.73 words/sec time_elapsed=289.69 sec
# epoch 13 (125/272) | step 3390 | avg_nll=7.04 avg_ppl=2.66 speed=3123.38 words/sec time_elapsed=290.42 sec
# epoch 13 (135/272) | step 3400 | avg_nll=7.14 avg_ppl=2.70 speed=2167.77 words/sec time_elapsed=291.49 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=5.422985553741455
# epoch 13 step 3400: save currently the best model to 'model.pt'
# epoch 13 (145/272) | step 3410 | avg_nll=6.55 avg_ppl=2.50 speed=1463.70 words/sec time_elapsed=293.05 sec
# epoch 13 (155/272) | step 3420 | avg_nll=7.03 avg_ppl=2.67 speed=2124.02 words/sec time_elapsed=294.13 sec
# epoch 13 (165/272) | step 3430 | avg_nll=6.83 avg_ppl=2.58 speed=3020.64 words/sec time_elapsed=294.89 sec
# epoch 13 (175/272) | step 3440 | avg_nll=7.37 avg_ppl=2.76 speed=3136.45 words/sec time_elapsed=295.64 sec
# epoch 13 (185/272) | step 3450 | avg_nll=7.71 avg_ppl=2.88 speed=3046.17 words/sec time_elapsed=296.40 sec
# epoch 13 (195/272) | step 3460 | avg_nll=6.66 avg_ppl=2.55 speed=3274.10 words/sec time_elapsed=297.10 sec
# epoch 13 (205/272) | step 3470 | avg_nll=6.25 avg_ppl=2.39 speed=3137.36 words/sec time_elapsed=297.83 sec
# epoch 13 (215/272) | step 3480 | avg_nll=7.08 avg_ppl=2.62 speed=3327.10 words/sec time_elapsed=298.53 sec
# epoch 13 (225/272) | step 3490 | avg_nll=7.02 avg_ppl=2.63 speed=3143.11 words/sec time_elapsed=299.27 sec
# epoch 13 (235/272) | step 3500 | avg_nll=7.32 avg_ppl=2.66 speed=3124.55 words/sec time_elapsed=300.04 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=5.582517147064209
# epoch 13 (245/272) | step 3510 | avg_nll=7.21 avg_ppl=2.67 speed=2331.94 words/sec time_elapsed=301.05 sec
# epoch 13 (255/272) | step 3520 | avg_nll=7.54 avg_ppl=2.77 speed=3047.48 words/sec time_elapsed=301.83 sec
# epoch 13 (265/272) | step 3530 | avg_nll=7.72 avg_ppl=2.88 speed=3207.35 words/sec time_elapsed=302.55 sec
# epoch 14 (3/272) | step 3540 | avg_nll=6.61 avg_ppl=2.52 speed=3344.86 words/sec time_elapsed=303.24 sec
# epoch 14 (13/272) | step 3550 | avg_nll=6.69 avg_ppl=2.46 speed=3357.99 words/sec time_elapsed=303.94 sec
# epoch 14 (23/272) | step 3560 | avg_nll=5.48 avg_ppl=2.17 speed=2736.07 words/sec time_elapsed=304.77 sec
# epoch 14 (33/272) | step 3570 | avg_nll=5.79 avg_ppl=2.20 speed=2368.40 words/sec time_elapsed=305.77 sec
# epoch 14 (43/272) | step 3580 | avg_nll=5.81 avg_ppl=2.23 speed=2311.74 words/sec time_elapsed=306.77 sec
# epoch 14 (53/272) | step 3590 | avg_nll=6.47 avg_ppl=2.41 speed=2602.75 words/sec time_elapsed=307.68 sec
# epoch 14 (63/272) | step 3600 | avg_nll=5.66 avg_ppl=2.19 speed=3236.02 words/sec time_elapsed=308.39 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=5.5567450523376465
# epoch 14 (73/272) | step 3610 | avg_nll=5.95 avg_ppl=2.29 speed=2169.02 words/sec time_elapsed=309.45 sec
# epoch 14 (83/272) | step 3620 | avg_nll=5.46 avg_ppl=2.17 speed=3183.77 words/sec time_elapsed=310.16 sec
# epoch 14 (93/272) | step 3630 | avg_nll=6.22 avg_ppl=2.34 speed=3729.68 words/sec time_elapsed=310.79 sec
# epoch 14 (103/272) | step 3640 | avg_nll=6.09 avg_ppl=2.34 speed=3922.68 words/sec time_elapsed=311.37 sec
# epoch 14 (113/272) | step 3650 | avg_nll=5.95 avg_ppl=2.27 speed=3811.48 words/sec time_elapsed=311.98 sec
# epoch 14 (123/272) | step 3660 | avg_nll=6.51 avg_ppl=2.45 speed=3382.52 words/sec time_elapsed=312.67 sec
# epoch 14 (133/272) | step 3670 | avg_nll=6.41 avg_ppl=2.43 speed=3302.89 words/sec time_elapsed=313.37 sec
# epoch 14 (143/272) | step 3680 | avg_nll=7.23 avg_ppl=2.67 speed=3108.52 words/sec time_elapsed=314.13 sec
# epoch 14 (153/272) | step 3690 | avg_nll=6.47 avg_ppl=2.44 speed=3738.08 words/sec time_elapsed=314.75 sec
# epoch 14 (163/272) | step 3700 | avg_nll=6.29 avg_ppl=2.40 speed=3778.86 words/sec time_elapsed=315.36 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=5.34998893737793
# epoch 14 step 3700: save currently the best model to 'model.pt'
# epoch 14 (173/272) | step 3710 | avg_nll=6.46 avg_ppl=2.45 speed=2367.05 words/sec time_elapsed=316.33 sec
# epoch 14 (183/272) | step 3720 | avg_nll=6.26 avg_ppl=2.37 speed=3190.42 words/sec time_elapsed=317.06 sec
# epoch 14 (193/272) | step 3730 | avg_nll=6.92 avg_ppl=2.59 speed=2823.95 words/sec time_elapsed=317.89 sec
# epoch 14 (203/272) | step 3740 | avg_nll=6.24 avg_ppl=2.39 speed=2621.12 words/sec time_elapsed=318.76 sec
# epoch 14 (213/272) | step 3750 | avg_nll=6.65 avg_ppl=2.49 speed=2294.15 words/sec time_elapsed=319.78 sec
# epoch 14 (223/272) | step 3760 | avg_nll=6.27 avg_ppl=2.37 speed=2644.17 words/sec time_elapsed=320.66 sec
# epoch 14 (233/272) | step 3770 | avg_nll=6.34 avg_ppl=2.43 speed=3395.39 words/sec time_elapsed=321.33 sec
# epoch 14 (243/272) | step 3780 | avg_nll=7.52 avg_ppl=2.75 speed=3367.19 words/sec time_elapsed=322.04 sec
# epoch 14 (253/272) | step 3790 | avg_nll=6.33 avg_ppl=2.43 speed=3361.91 words/sec time_elapsed=322.72 sec
# epoch 14 (263/272) | step 3800 | avg_nll=6.60 avg_ppl=2.45 speed=3330.52 words/sec time_elapsed=323.43 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=5.448562145233154
# epoch 15 (1/272) | step 3810 | avg_nll=6.18 avg_ppl=2.41 speed=2489.37 words/sec time_elapsed=324.33 sec
# epoch 15 (11/272) | step 3820 | avg_nll=5.25 avg_ppl=2.07 speed=3326.52 words/sec time_elapsed=325.02 sec
# epoch 15 (21/272) | step 3830 | avg_nll=5.10 avg_ppl=2.02 speed=3381.05 words/sec time_elapsed=325.71 sec
# epoch 15 (31/272) | step 3840 | avg_nll=4.84 avg_ppl=1.97 speed=3170.22 words/sec time_elapsed=326.43 sec
# epoch 15 (41/272) | step 3850 | avg_nll=5.76 avg_ppl=2.22 speed=3292.83 words/sec time_elapsed=327.13 sec
# epoch 15 (51/272) | step 3860 | avg_nll=5.50 avg_ppl=2.17 speed=3481.41 words/sec time_elapsed=327.78 sec
# epoch 15 (61/272) | step 3870 | avg_nll=5.52 avg_ppl=2.13 speed=3997.86 words/sec time_elapsed=328.37 sec
# epoch 15 (71/272) | step 3880 | avg_nll=5.45 avg_ppl=2.12 speed=3367.95 words/sec time_elapsed=329.06 sec
# epoch 15 (81/272) | step 3890 | avg_nll=4.85 avg_ppl=1.97 speed=3373.37 words/sec time_elapsed=329.74 sec
# epoch 15 (91/272) | step 3900 | avg_nll=6.16 avg_ppl=2.33 speed=3361.92 words/sec time_elapsed=330.43 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=5.563937664031982
# epoch 15 (101/272) | step 3910 | avg_nll=5.60 avg_ppl=2.15 speed=1677.64 words/sec time_elapsed=331.83 sec
# epoch 15 (111/272) | step 3920 | avg_nll=5.80 avg_ppl=2.26 speed=2285.23 words/sec time_elapsed=332.83 sec
# epoch 15 (121/272) | step 3930 | avg_nll=5.76 avg_ppl=2.21 speed=2433.14 words/sec time_elapsed=333.78 sec
# epoch 15 (131/272) | step 3940 | avg_nll=5.75 avg_ppl=2.21 speed=3251.86 words/sec time_elapsed=334.50 sec
# epoch 15 (141/272) | step 3950 | avg_nll=6.01 avg_ppl=2.27 speed=3528.76 words/sec time_elapsed=335.16 sec
# epoch 15 (151/272) | step 3960 | avg_nll=5.64 avg_ppl=2.20 speed=3192.34 words/sec time_elapsed=335.88 sec
# epoch 15 (161/272) | step 3970 | avg_nll=5.72 avg_ppl=2.21 speed=3222.37 words/sec time_elapsed=336.60 sec
# epoch 15 (171/272) | step 3980 | avg_nll=6.52 avg_ppl=2.44 speed=3666.98 words/sec time_elapsed=337.23 sec
# epoch 15 (181/272) | step 3990 | avg_nll=5.73 avg_ppl=2.22 speed=3521.19 words/sec time_elapsed=337.89 sec
# epoch 15 (191/272) | step 4000 | avg_nll=6.43 avg_ppl=2.37 speed=4048.44 words/sec time_elapsed=338.48 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=5.565710544586182
# epoch 15 (201/272) | step 4010 | avg_nll=5.99 avg_ppl=2.30 speed=2311.03 words/sec time_elapsed=339.47 sec
# epoch 15 (211/272) | step 4020 | avg_nll=6.53 avg_ppl=2.44 speed=3538.39 words/sec time_elapsed=340.14 sec
# epoch 15 (221/272) | step 4030 | avg_nll=6.25 avg_ppl=2.37 speed=3655.64 words/sec time_elapsed=340.77 sec
# epoch 15 (231/272) | step 4040 | avg_nll=6.49 avg_ppl=2.44 speed=3728.17 words/sec time_elapsed=341.39 sec
# epoch 15 (241/272) | step 4050 | avg_nll=6.10 avg_ppl=2.29 speed=3636.66 words/sec time_elapsed=342.04 sec
# epoch 15 (251/272) | step 4060 | avg_nll=5.83 avg_ppl=2.25 speed=3787.07 words/sec time_elapsed=342.65 sec
# epoch 15 (261/272) | step 4070 | avg_nll=6.09 avg_ppl=2.32 speed=3823.48 words/sec time_elapsed=343.26 sec
# epoch 15 (271/272) | step 4080 | avg_nll=5.25 avg_ppl=2.10 speed=3202.77 words/sec time_elapsed=343.97 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]

    best_generation = None
    best_score = float('-inf')

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)

            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)


    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# Use device: cpu
# 100%|██████████| 486/486 [00:51<00:00,  9.42it/s]
# Corpus BLEU: 56.50580595062262

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  you re embarrassing me .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she stared at up with him .
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not married .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going back .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re embarrassing me .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m going .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m not a student .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m retired .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you re just a coward .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?

# %% [markdown]
# **B) i-vocab size:** >> 3200 (token_embeddings): Embedding(3200, 32)
#
# **ii- padding:** >> This suggests that approximately 1500 words are processed per second.
#
# However, the exact batch size isn't directly stated. Assuming a typical setting for a Transformer model, a common batch size might be 64 sentences with an average length of 20 tokens each, resulting in 1280 tokens per batch.
#
# As for the proportion of <pad> tokens, it's often observed in practice that padding can make up about 20-30% of tokens in a batch, especially in batches with variable-length sequences.
#
# **iii-purpose of the model:** >>The model parameters are saved to model.pt to retain the best performing model during training. This is done to ensure that the model with the lowest validation perplexity (ppl) is preserved, which is useful for later evaluation or deployment.

# %% [markdown]
# **Manual validation:**
#
# 1) incorrect translation: Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she stared at up with him .
# no indication with whom she was smilling? redundancy with the word smiled
#
# 2) perdre means lose >>  Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going back
# as well here
#
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not married .
#
# 3)missing a word Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m going .
#
#
# 4) change of the worder of the sentence but not the meaning so okay
#
#  Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you re just a coward .
#
#
# 5) there were excellent sentences as well like here
#
#  ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  you re embarrassing me .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher
